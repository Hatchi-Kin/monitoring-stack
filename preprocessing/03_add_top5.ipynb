# %%
import os
import pickle
import random

from pathlib import Path
from utils.music_utils import *

import numpy as np

# %%
DATASET = Path("MegaSet")

mp3_files = list(DATASET.glob("**/*.mp3"))
print("Found {} mp3 files".format(len(mp3_files)))
# Out:
# Found 16428 mp3 files

# %%
valid_mp3_files = []
invalid_mp3_files = []
total_mp3_files = len(mp3_files)

for mp3_file in mp3_files:
    if not check_predictions_87(mp3_file) or not check_embeddings_512(mp3_file):
        invalid_mp3_files.append(mp3_file)
    else:
        valid_mp3_files.append(mp3_file)

# calculate the percentage of valid mp3 files
percentage_valid = len(valid_mp3_files) / total_mp3_files * 100
print(f"found {len(valid_mp3_files)} valid pkl files out of {total_mp3_files}, percentage valid: {percentage_valid:.2f}%")
# Out:
# found 16428 valid pkl files out of 16428, percentage valid: 100.00%

# %%
pkl_files = list(DATASET.glob("**/*.pkl"))
long_fields = []
for path in pkl_files:
    with path.open("rb") as f:
        file_info = pickle.load(f)
        title = file_info.get("title")
        artist = file_info.get("artist")
        if (
            (not title or len(title) > 160)
            or (not artist or len(artist) > 160)
        ):
            long_fields.append(path)

# Print the paths of the files with a title or artist field of length > 120
for path in long_fields:
    print(path)

# %%
#######################################################################################""

# %%
# for each mp3 file in Path(), pass the path of mp3 file to file 
# and path to openl3-music-mel128-emb512-3.pb to the function get_top_5_genres
# data["top_5_genres"] = get_top_5_genres(file, path)
# then add the new field to the pkl file and save it

pkl_files = list(DATASET.glob("**/*.pkl"))

for path in pkl_files:
    with path.open("rb") as f:
        file_info = pickle.load(f)
        top5_list = get_top_5_genres(file_info["filepath"], "utils/mtg_jamendo_genre.json")
        file_info['top_5_genres'] = top5_list
        with path.open("wb") as f:
            pickle.dump(file_info, f)

# %%
print_info(pick_random_mp3(DATASET))
# Out:
# filename: 09 I Don't Love You Anymore.mp3
# filepath: MegaSet/William Fitzsimmons/William Fitzsimmons - Goodnight/09 I Don't Love You Anymore.mp3
# folder: MegaSet/William Fitzsimmons/William Fitzsimmons - Goodnight
# filesize: 10.78
# title: I Don't Love You Anymore
# artist: William Fitzsimmons
# album: Goodnight
# year: 2006
# tracknumber: 9
# genre: Folk
# predictions_87: [0.00404966 0.00299255 0.0018665  0.00393452 0.00312867 0.10258203
#  0.00329245 0.13125642 0.02044186 0.02209434 0.00147272 0.00263616
#  0.00127668 0.01579212 0.0147085  0.0457707  0.00284004 0.11371269
#  0.00704045 0.00086865 0.01300108 0.02638454 0.00319499 0.00337267
#  0.00244311 0.00065258 0.00141362 0.00900973 0.00112069 0.0010447
#  0.00078464 0.12389961 0.00065528 0.08252712 0.00151368 0.00660835
#  0.01255971 0.0005132  0.0440952  0.195749   0.00377892 0.00751568
#  0.0012831  0.00368763 0.00129561 0.00335999 0.01046178 0.00172168
#  0.00111907 0.00689667 0.07067776 0.00290688 0.05894087 0.01343957
#  0.01991178 0.00246904 0.0122342  0.02854332 0.00397783 0.00630178
#  0.00686774 0.07808863 0.00225314 0.02124433 0.24656634 0.15713416
#  0.05838256 0.01016016 0.0128352  0.01455304 0.00235184 0.0061308
#  0.00524668 0.00426538 0.09566238 0.00224444 0.0532852  0.00504238
#  0.1241356  0.00180886 0.00682717 0.0023861  0.00297834 0.00207931
